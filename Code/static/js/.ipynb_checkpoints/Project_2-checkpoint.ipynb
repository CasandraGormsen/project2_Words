# %%
# Dependencies
import requests
import json
import config
from random_word import RandomWords

# %%
words = set()

# %%
word = RandomWords()

# Return a single random word
word.get_random_word()
# Out:
# 'frontally'

# %%
for x in range(10):
    words.add(word.get_random_word())

# %%
print(words)
# Out:
# {'ignitable', 'diffend', 'torchlight', 'elevation', 'cinemas', 'qazis', 'rusting', 'presbyte', 'faeces', 'digress'}

# %%
# URL for GET requests to retrieve vehicle data
url = "https://www.dictionaryapi.com/api/v3/references"

def dictionary(test_word):
    return url + "/collegiate/json/" + test_word + "?key=" + config.API_KEY_Dictionary
def thesaurus(test_word):
    return url + "/thesaurus/json/" + test_word +"?key=" + config.API_KEY_Thesaurus

# %%
dictionary = "Banana"

# %%
# Pretty print JSON for all launchpads

for word in list(words):
    word_url = dictionary(word)
    response = requests.get(word_url).json()
    print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     "hounders",
#     "launders",
#     "joinders",
#     "maunders",
#     "sanders",
#     "Randers",
#     "sunders",
#     "blunders",
#     "zanders",
#     "bounders",
#     "jauntier",
#     "founders",
#     "joinder",
#     "funders",
#     "jointers",
#     "jaunces",
#     "launder",
#     "maunder",
#     "plunders",
#     "pounders"
# ]
# [
#     "bran",
#     "Quran",
#     "burin",
#     "burn",
#     "borane",
#     "furan",
#     "bourn",
#     "burden",
#     "brain",
#     "bureau",
#     "brawn",
#     "burial",
#     "Barany",
#     "burins",
#     "burkas",
#     "burlap",
#     "Arran",
#     "Koran",
#     "bur",
#     "burb"
# ]
# [
#     "non-aesthetic",
#     "asthmatics",
#     "nonaquatic",
#     "nonautomatic",
#     "nonascetic",
#     "antiasthmatic",
#     "non-Catholics",
#     "asthmatic",
#     "nonactivated",
#     "nonaromatic",
#     "nonskaters",
#     "nonathletic",
#     "nonstarters",
#     "noncharismatics",
#     "nonsteroids",
#     "nonmathematical",
#     "nonstick",
#     "nonmathematicians",
#     "nonstories",
#     "anti-asthmatic"
# ]
# [
#     {
#         "date": "14th century{ds||2|a|}",
#         "def": [
#             {
#                 "sseq": [
#                     [
#                         [
#                             "sense",
#                             {
#                                 "dt": [
#                                     [
#                                         "text",
#                                         "{bc}to assume an air of superiority "
#                                     ],
#                                     [
#                                         "vis",
#                                         [
#                                             {
#                                                 "t": "The writer treats her readers as equals and never {wi}condescends{/wi} to them."
#                                             }
#                                         ]
#                                     ]
#                                 ],
#                                 "sn": "1"
#                             }
#                         ]
#                     ],
#                     [
#                         [
#                             "sense",
#                             {
#                                 "dt": [
#                                     [
#                                         "text",
#                                         "{bc}to descend to a less formal or dignified level {bc}{sx|unbend||} "
#                                     ],
#                                     [
#                                         "vis",
#                                         [
#                                             {
#                                                 "t": "would not {wi}condescend{/wi} to respond to such a crass remark"
#                                             }
#                                         ]
#                                     ]
#                                 ],
#                                 "sn": "2 a"
#                             }
#                         ],
#                         [
#                             "sense",
#                             {
#                                 "dt": [
#                                     [
#                                         "text",
#                                         "{bc}to waive the privileges of rank"
#                                     ]
#                                 ],
#                                 "sn": "b"
#                             }
#                         ]
#                     ]
#                 ],
#                 "vd": "intransitive verb"
#             }
#         ],
#         "et": [
#             [
#                 "text",
#                 "Middle English, from Anglo-French {it}condescendre{/it}, from Late Latin {it}condescendere{/it}, from Latin {it}com-{/it} + {it}descendere{/it} to descend"
#             ]
#         ],
#         "fl": "verb",
#         "hwi": {
#             "hw": "con*de*scend",
#             "prs": [
#                 {
#                     "mw": "\u02cck\u00e4n-di-\u02c8send",
#                     "sound": {
#                         "audio": "condes01",
#                         "ref": "c",
#                         "stat": "1"
#                     }
#                 }
#             ]
#         },
#         "ins": [
#             {
#                 "if": "con*de*scend*ed"
#             },
#             {
#                 "if": "con*de*scend*ing"
#             },
#             {
#                 "if": "con*de*scends"
#             }
#         ],
#         "meta": {
#             "id": "condescend",
#             "offensive": false,
#             "section": "alpha",
#             "sort": "035514800",
#             "src": "collegiate",
#             "stems": [
#                 "condescend",
#                 "condescended",
#                 "condescending",
#                 "condescends"
#             ],
#             "uuid": "fe901840-f23a-415e-baf4-aae2260b6a15"
#         },
#         "shortdef": [
#             "to assume an air of superiority",
#             "to descend to a less formal or dignified level : unbend",
#             "to waive the privileges of rank"
#         ]
#     }
# ]
# [
#     {
#         "date": "1897",
#         "def": [
#             {
#                 "sseq": [
#                     [
#                         [
#                             "sense",
#                             {
#                                 "dt": [
#                                     [
#                                         "text",
#                                         "{bc}a material made by compressing {a_link|fibers} (as of wood) into stiff sheets"
#                                     ]
#                                 ],
#                                 "sdsense": {
#                                     "dt": [
#                                         [
#                                             "text",
#                                             "{bc}{sx|cardboard||}"
#                                         ]
#                                     ],
#                                     "sd": "also"
#                                 }
#                             }
#                         ]
#                     ]
#                 ]
#             }
#         ],
#         "fl": "noun",
#         "hwi": {
#             "hw": "fi*ber*board",
#             "prs": [
#                 {
#                     "mw": "\u02c8f\u012b-b\u0259r-\u02ccb\u022frd",
#                     "sound": {
#                         "audio": "fiberb01",
#                         "ref": "c",
#                         "stat": "1"
#                     }
#                 }
#             ]
#         },
#         "meta": {
#             "id": "fiberboard",
#             "offensive": false,
#             "section": "alpha",
#             "sort": "061017000",
#             "src": "collegiate",
#             "stems": [
#                 "fiberboard",
#                 "fiberboards",
#                 "fibreboard",
#                 "fibreboards"
#             ],
#             "uuid": "7ab6c4dd-3d52-4c1a-9644-e9a82eb4ae6c"
#         },
#         "shortdef": [
#             "a material made by compressing fibers (as of wood) into stiff sheets; also : cardboard"
#         ]
#     }
# ]
# [
#     {
#         "date": "1901",
#         "def": [
#             {
#                 "sseq": [
#                     [
#                         [
#                             "sense",
#                             {
#                                 "dt": [
#                                     [
#                                         "text",
#                                         "{bc}{sx|firebreak||}"
#                                     ]
#                                 ]
#                             }
#                         ]
#                     ]
#                 ]
#             }
#         ],
#         "fl": "noun",
#         "hwi": {
#             "hw": "fire line"
#         },
#         "meta": {
#             "id": "fire line",
#             "offensive": false,
#             "section": "alpha",
#             "sort": "061430000",
#             "src": "collegiate",
#             "stems": [
#                 "fire line",
#                 "fire lines"
#             ],
#             "uuid": "2469bcf8-39cb-46c7-a160-b1b215c72e7c"
#         },
#         "shortdef": [
#             "firebreak"
#         ]
#     }
# ]
# [
#     {
#         "date": "1864",
#         "def": [
#             {
#                 "sseq": [
#                     [
#                         [
#                             "sense",
#                             {
#                                 "dt": [
#                                     [
#                                         "text",
#                                         "{bc}an article (such as a book) whose sales are among the highest of its class"
#                                     ]
#                                 ]
#                             }
#                         ]
#                     ]
#                 ]
#             }
#         ],
#         "fl": "noun",
#         "hwi": {
#             "hw": "best sell*er",
#             "prs": [
#                 {
#                     "mw": "\u02c8bes(t)-\u02c8se-l\u0259r",
#                     "sound": {
#                         "audio": "bests01w",
#                         "ref": "c",
#                         "stat": "1"
#                     }
#                 }
#             ]
#         },
#         "meta": {
#             "id": "best seller",
#             "offensive": false,
#             "section": "alpha",
#             "sort": "020175000",
#             "src": "collegiate",
#             "stems": [
#                 "best seller",
#                 "best sellers",
#                 "best-sellerdom",
#                 "best-selling",
#                 "bestseller",
#                 "bestsellerdoms"
#             ],
#             "uuid": "dd64168c-e0c3-4bd8-9b47-f205ac81eedd"
#         },
#         "shortdef": [
#             "an article (such as a book) whose sales are among the highest of its class"
#         ],
#         "uros": [
#             {
#                 "fl": "noun",
#                 "prs": [
#                     {
#                         "mw": "\u02c8bes(t)-\u02c8se-l\u0259r-d\u0259m",
#                         "sound": {
#                             "audio": "bests02w",
#                             "ref": "c",
#                             "stat": "1"
#                         }
#                     }
#                 ],
#                 "ure": "best-sell*er*dom"
#             },
#             {
#                 "fl": "adjective",
#                 "prs": [
#                     {
#                         "mw": "\u02c8bes(t)-\u02c8se-li\u014b",
#                         "sound": {
#                             "audio": "bests03w",
#                             "ref": "c",
#                             "stat": "1"
#                         }
#                     }
#                 ],
#                 "ure": "best-sell*ing"
#             }
#         ],
#         "vrs": [
#             {
#                 "va": "best*sell*er",
#                 "vl": "or"
#             }
#         ]
#     }
# ]
# [
#     "end plate",
#     "one-piece",
#     "endive",
#     "centerpiece",
#     "endophyte",
#     "codpiece",
#     "endpaper",
#     "earpiece",
#     "endpapers",
#     "eyepiece",
#     "headpiece",
#     "nosepiece",
#     "one-piecer",
#     "one-pieces",
#     "set-piece",
#     "sidepiece",
#     "two-piece",
#     "centerpieces",
#     "mantelpiece",
#     "one-piecers"
# ]
# [
#     {
#         "date": "circa 1829{ds||1||}",
#         "def": [
#             {
#                 "sseq": [
#                     [
#                         [
#                             "sense",
#                             {
#                                 "dt": [
#                                     [
#                                         "text",
#                                         "{bc}a branch of dynamics that deals with the motion of air and other gaseous fluids and with the forces acting on bodies in motion relative to such fluids"
#                                     ]
#                                 ],
#                                 "sn": "1"
#                             }
#                         ]
#                     ],
#                     [
#                         [
#                             "sense",
#                             {
#                                 "dt": [
#                                     [
#                                         "text",
#                                         "{bc}the qualities of an object that affect how easily it is able to move through the air "
#                                     ],
#                                     [
#                                         "vis",
#                                         [
#                                             {
#                                                 "aq": {
#                                                     "auth": "Clive Irving"
#                                                 },
#                                                 "t": "The {wi}aerodynamics{/wi} \u2026 turned out to be better than his engineers promised. The 777 was so slippery that its cruise speed was upped from .83 Mach to .84 \u2026"
#                                             }
#                                         ]
#                                     ]
#                                 ],
#                                 "sn": "2"
#                             }
#                         ]
#                     ]
#                 ]
#             }
#         ],
#         "et": [
#             [
#                 "text",
#                 "{et_link|aero-|aer-} + {et_link|dynamics:1|dynamics:1} (on the model of {et_link|hydrodynamics|hydrodynamics})"
#             ]
#         ],
#         "fl": "noun, plural in form but singular or plural in construction",
#         "hwi": {
#             "hw": "aero*dy*nam*ics",
#             "prs": [
#                 {
#                     "mw": "\u02ccer-\u014d-d\u012b-\u02c8na-miks",
#                     "sound": {
#                         "audio": "aerody04",
#                         "ref": "c",
#                         "stat": "1"
#                     }
#                 }
#             ]
#         },
#         "meta": {
#             "id": "aerodynamics",
#             "offensive": false,
#             "section": "alpha",
#             "sort": "011137000",
#             "src": "collegiate",
#             "stems": [
#                 "aerodynamic",
#                 "aerodynamical",
#                 "aerodynamically",
#                 "aerodynamics"
#             ],
#             "uuid": "3bd88c9b-b800-430d-9b5f-3bbb7be021d3"
#         },
#         "shortdef": [
#             "a branch of dynamics that deals with the motion of air and other gaseous fluids and with the forces acting on bodies in motion relative to such fluids",
#             "the qualities of an object that affect how easily it is able to move through the air"
#         ],
#         "uros": [
#             {
#                 "fl": "adjective",
#                 "prs": [
#                     {
#                         "mw": "\u02ccer-\u014d-d\u012b-\u02c8na-mik",
#                         "sound": {
#                             "audio": "aerody02",
#                             "ref": "c",
#                             "stat": "1"
#                         }
#                     }
#                 ],
#                 "ure": "aero*dy*nam*ic",
#                 "vrs": [
#                     {
#                         "prs": [
#                             {
#                                 "mw": "\u02ccer-\u014d-d\u012b-\u02c8na-mi-k\u0259l",
#                                 "sound": {
#                                     "audio": "aerody05",
#                                     "ref": "c",
#                                     "stat": "1"
#                                 }
#                             }
#                         ],
#                         "va": "aero*dy*nam*i*cal",
#                         "vl": "or less commonly"
#                     }
#                 ]
#             },
#             {
#                 "fl": "adverb",
#                 "prs": [
#                     {
#                         "mw": "\u02ccer-\u014d-d\u012b-\u02c8na-mi-k(\u0259-)l\u0113",
#                         "sound": {
#                             "audio": "aerody03",
#                             "ref": "c",
#                             "stat": "1"
#                         }
#                     }
#                 ],
#                 "ure": "aero*dy*nam*i*cal*ly"
#             }
#         ]
#     }
# ]
# [
#     "teetotalism",
#     "teetotalist",
#     "teetotalisms",
#     "teetotalists",
#     "teetotal",
#     "teetotaler",
#     "teetotalers",
#     "teetotaller",
#     "teetotally",
#     "totaling",
#     "teetotallers",
#     "metaling",
#     "pedestaling",
#     "teetering",
#     "teething",
#     "totalling",
#     "revictualing",
#     "coaling",
#     "dealing",
#     "descaling"
# ]

# %%
# Pretty print JSON for a specific launchpad
response = requests.get(thesaurus_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     "exigent",
#     "exigency"
# ]
